# %%
from sklearn.model_selection import train_test_split

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../Advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df['total sell'] = df['TV'] + df['Radio'] + df['Newspaper']
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales  total sell
# 0           1  230.1   37.8       69.2   22.1       337.1
# 1           2   44.5   39.3       45.1   10.4       128.9
# 2           3   17.2   45.9       69.3    9.3       132.4
# 3           4  151.5   41.3       58.5   18.5       251.3
# 4           5  180.8   10.8       58.4   12.9       250.0

# %%
sns.scatterplot(data=df, x='total sell', y='Sales')
# Out:
# <Axes: xlabel='total sell', ylabel='Sales'>

# %%
sns.regplot(data=df, x='total sell', y='Sales')
# Out:
# <Axes: xlabel='total sell', ylabel='Sales'>
