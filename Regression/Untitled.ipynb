# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
p = pd.read_csv('house-prices.csv')

target  = p["Price"]
features = p[['SqFt','Bedrooms','Bathrooms']]

x_train , x_test, y_train, y_test = train_test_split(features, target, test_size=0.33, shuffle= False)

x_train
# Out:
#     SqFt  Bedrooms  Bathrooms
# 0   1790         2          2
# 1   2030         4          2
# 2   1740         3          2
# 3   1980         3          2
# 4   2130         3          3
# ..   ...       ...        ...
# 80  2190         3          3
# 81  2140         4          3
# 82  2050         2          2
# 83  2410         3          3
# 84  1520         2          2
#
# [85 rows x 3 columns]

# %%
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(x_test)

# %% [markdown]
# mse = mean_squared_error
# np.sqr()

# %%
#lin_reg.coef_
#lin_reg.intercept_

# %%
mse = mean_squared_error(y_pred, y_test)
np.sqrt(mse)
# Out:
# 21919.17428865911

# %%
target.describe()
# Out:
# count       128.000000
# mean     130427.343750
# std       26868.770371
# min       69100.000000
# 25%      111325.000000
# 50%      125950.000000
# 75%      148250.000000
# max      211200.000000
# Name: Price, dtype: float64
